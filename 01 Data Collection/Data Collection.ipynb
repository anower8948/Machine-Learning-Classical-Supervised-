# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("customers.csv")

# %%
df.head(2)
# Out:
#    Index      Customer Id First Name Last Name           Company  \
# 0      1  ffeCAb7AbcB0f07      Jared    Jarvis  Sanchez-Fletcher
# 1      2  b687FfC4F1600eC      Marie    Malone         Mckay PLC
#
#              City   Country             Phone 1               Phone 2  \
# 0   Hatfieldshire   Eritrea  274.188.8773x41185  001-215-760-4642x969
# 1  Robertsonburgh  Botswana        283-236-9529   (189)129-8356x63741
#
#                            Email Subscription Date                     Website
# 0  gabriellehartman@benjamin.com        2021-11-11  https://www.mccarthy.info/
# 1           kstafford@sexton.com        2021-05-14    http://www.reynolds.com/

# %%
df_excel = pd.read_excel("dataset.xlsx")

# %%
df_excel.head(2)
# Out:
#    age workclass  fnlwgt education  education.num marital.status  \
# 0   90         ?   77053   HS-grad              9        Widowed
# 1   82   Private  132870   HS-grad              9        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K

# %%
excel_file = pd.ExcelFile("dataset.xlsx")
print(excel_file.sheet_names)
# Out:
# ['Worksheet']

# %%
df2 = pd.read_excel("dataset.xlsx", sheet_name = "Worksheet")

# %%
df2.tail(2)
# Out:
#        age workclass  fnlwgt education  education.num marital.status  \
# 32559   58   Private  151910   HS-grad              9        Widowed
# 32560   22   Private  201490   HS-grad              9  Never-married
#
#          occupation relationship   race     sex  capital.gain  capital.loss  \
# 32559  Adm-clerical    Unmarried  White  Female             0             0
# 32560  Adm-clerical    Own-child  White    Male             0             0
#
#        hours.per.week native.country income
# 32559              40  United-States  <=50K
# 32560              20  United-States  <=50K

# %%
df3 = pd.read_excel("dataset.xlsx", sheet_name = 0)
df3.tail(2)
# Out:
#        age workclass  fnlwgt education  education.num marital.status  \
# 32559   58   Private  151910   HS-grad              9        Widowed
# 32560   22   Private  201490   HS-grad              9  Never-married
#
#          occupation relationship   race     sex  capital.gain  capital.loss  \
# 32559  Adm-clerical    Unmarried  White  Female             0             0
# 32560  Adm-clerical    Own-child  White    Male             0             0
#
#        hours.per.week native.country income
# 32559              40  United-States  <=50K
# 32560              20  United-States  <=50K

# %%
user = pd.read_json("house-price.json")

# %%
print(user.head(2))
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished

# %%
user.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
